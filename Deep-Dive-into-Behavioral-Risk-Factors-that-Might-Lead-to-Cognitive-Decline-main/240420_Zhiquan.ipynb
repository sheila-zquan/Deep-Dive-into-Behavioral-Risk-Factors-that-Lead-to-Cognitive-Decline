# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_full = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Mining/Data/Copy of df2022_WiClass.csv')
Features = ['SDHUTILS', 'SDHTRNSP', 'SDHSTRE1', 'MARIJAN1', 'MENTCIGS', 'MENTECIG', 'HEATTBCO', 'ASBIBING', 'ASBIADVC', 'ASBIRDUC', 'FIREARM5', 'GUNLOAD', 'RCSXBRTH', 'CASTHNO2', 'PFPPRVN4', 'TYPCNTR9', 'BRTHCNT4', 'WHEREGET', 'NOBCUSE8', 'RRTREAT', 'RRHCARE4', 'RRPHYSM2', '_RFHLTH', '_PHYS14D', '_MENT14D']
df = df_full[Features]

# %%
df.shape
# Out:
# (63630, 25)

# %%
# features_kept=[]
# df2 = df[features_kept]

# %%
def ToOrdinal(df, column_name, Never=8, Never_to_0=True):
  df2 = df.copy()
  df2[column_name].fillna(0, inplace=True)
  df2[column_name] = df2[column_name].astype(int)
  if Never:
    if Never_to_0:
      df2[column_name].replace(Never, 0, inplace=True)
    else:
      Never_to = df2[column_name].value_counts().sort_index(ascending=False).index[0]+1
      df2[column_name].replace(Never, Never_to, inplace=True)

  return df2

def ToBinary(test_df, column_name, inf_replacement=7, nan_replacement=7):
    test_df2 = test_df.copy()
    test_df2[column_name] = test_df2[column_name].fillna(nan_replacement)  # Replace NaN values with specified value
    test_df2[column_name] = test_df2[column_name].replace([np.inf, -np.inf], inf_replacement)  # Replace inf values with specified value
    test_df2[column_name] = test_df2[column_name].astype(int)
    test_df2[column_name].replace(2, 0, inplace=True)
    print(test_df2[column_name].unique())
    return test_df2

def ToNominal(df, column_name, categories):
  df2 = df.copy()
  df2[column_name].fillna(10000, inplace=True)
  column_keys = df2[column_name].value_counts().index.tolist()
  column_keys.sort()

  mapping = {column_keys[i]: categories[i] for i in range(len(column_keys))}
  df2[column_name] = df2[column_name].map(mapping)
  return df2

# %%
def Impute(df, column_name, Unknown=7, Missing=9):
  df2 = df.copy()

  mode = df2[column_name].mode()[0]
  df2[column_name].replace([Unknown, Missing], mode, inplace=True)

  return df2

def OneHotEncoding(df):
  df2 = df.copy()
  one_hot_columns = df2.dtypes[df2.dtypes == 'object'].index.tolist()
  for column in one_hot_columns:
    one_hot_encoding = pd.get_dummies(df2[column], dtype='int')
    df2 = pd.concat([df2, one_hot_encoding], axis=1)
    df2.drop(columns=[column], inplace = True)
    if 'Missing' in df2.columns:
      df2.drop(columns=['Missing'], inplace = True)

  return df2

# %%
df3 = df[['SDHUTILS', 'SDHTRNSP', 'SDHSTRE1', 'MARIJAN1', 'MENTCIGS', 'MENTECIG', 'HEATTBCO', 'ASBIBING', 'ASBIADVC', 'ASBIRDUC', 'FIREARM5', 'GUNLOAD', 'RCSXBRTH', 'CASTHNO2', 'PFPPRVN4', 'TYPCNTR9', 'BRTHCNT4', 'WHEREGET', 'NOBCUSE8', 'RRTREAT', 'RRHCARE4', 'RRPHYSM2', '_RFHLTH', '_PHYS14D', '_MENT14D']]

# %%
df3.head(10)
# Out:
#    SDHUTILS  SDHTRNSP  SDHSTRE1  MARIJAN1  MENTCIGS  MENTECIG  HEATTBCO  \
# 0       2.0       2.0       5.0       NaN       NaN       NaN       NaN
# 1       1.0       2.0       5.0       NaN       NaN       NaN       NaN
# 2       2.0       2.0       4.0       NaN       NaN       NaN       NaN
# 3       2.0       2.0       5.0       NaN       NaN       NaN       NaN
# 4       2.0       2.0       4.0       NaN       NaN       NaN       NaN
# 5       2.0       2.0       4.0       NaN       NaN       NaN       NaN
# 6       2.0       2.0       5.0       NaN       NaN       NaN       NaN
# 7       2.0       2.0       5.0       NaN       NaN       NaN       NaN
# 8       2.0       2.0       4.0       NaN       NaN       NaN       NaN
# 9       2.0       2.0       3.0       NaN       NaN       NaN       NaN
#
#    ASBIBING  ASBIADVC  ASBIRDUC  ...  TYPCNTR9  BRTHCNT4  WHEREGET  NOBCUSE8  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
def check_nans(df):
  nans = []
  for feature in df.columns:
    print(f'There are {df[feature].isna().sum()} missing values in {feature}')
    nans.append(df[feature].isna().sum())
  return nans

# %%
check_nans(df3)
# Out:
# There are 11251 missing values in SDHUTILS
# There are 11304 missing values in SDHTRNSP
# There are 11437 missing values in SDHSTRE1
# There are 32441 missing values in MARIJAN1
# There are 62514 missing values in MENTCIGS
# There are 63403 missing values in MENTECIG
# There are 61841 missing values in HEATTBCO
# There are 54279 missing values in ASBIBING
# There are 54412 missing values in ASBIADVC
# There are 56659 missing values in ASBIRDUC
# There are 61952 missing values in FIREARM5
# There are 62966 missing values in GUNLOAD
# There are 63333 missing values in RCSXBRTH
# There are 63025 missing values in CASTHNO2
# There are 62570 missing values in PFPPRVN4
# There are 62851 missing values in TYPCNTR9
# There are 62853 missing values in BRTHCNT4
# There are 62949 missing values in WHEREGET
# There are 63373 missing values in NOBCUSE8
# There are 21728 missing values in RRTREAT
# There are 21840 missing values in RRHCARE4
# There are 21919 missing values in RRPHYSM2
# ...

# %%
#drop >30000 missing value
# 'SDHUTILS', binary
# 'SDHTRNSP', binary
# 'SDHSTRE1', cat, ordinal
# 'MARIJAN1', D
# 'MENTCIGS', D
# 'MENTECIG', D
# 'HEATTBCO', D
# 'ASBIBING', D
# 'ASBIADVC', D
# 'ASBIRDUC', D
# 'FIREARM5', D
# 'GUNLOAD', D
# 'RCSXBRTH', D
# 'CASTHNO2', D
# 'PFPPRVN4', D
# 'TYPCNTR9', D
# 'BRTHCNT4', D
# 'WHEREGET', D
# 'NOBCUSE8', D
# 'RRTREAT', cat,nominal
# 'RRHCARE4', cat,nominal
# 'RRPHYSM2', binary
# '_RFHLTH', cat,nominal
# '_PHYS14D', cat,nominal
# '_MENT14D', cat,nominal

# %%
df4 = df3[['SDHUTILS', 'SDHTRNSP', 'SDHSTRE1','RRTREAT', 'RRHCARE4', 'RRPHYSM2', '_RFHLTH', '_PHYS14D', '_MENT14D']]

# %%
df4.head(10)
# Out:
#    SDHUTILS  SDHTRNSP  SDHSTRE1  RRTREAT  RRHCARE4  RRPHYSM2  _RFHLTH  \
# 0       2.0       2.0       5.0      NaN       NaN       NaN      1.0
# 1       1.0       2.0       5.0      NaN       NaN       NaN      1.0
# 2       2.0       2.0       4.0      NaN       NaN       NaN      1.0
# 3       2.0       2.0       5.0      NaN       NaN       NaN      1.0
# 4       2.0       2.0       4.0      NaN       NaN       NaN      2.0
# 5       2.0       2.0       4.0      NaN       NaN       NaN      1.0
# 6       2.0       2.0       5.0      NaN       NaN       NaN      1.0
# 7       2.0       2.0       5.0      NaN       NaN       NaN      1.0
# 8       2.0       2.0       4.0      NaN       NaN       NaN      1.0
# 9       2.0       2.0       3.0      NaN       NaN       NaN      1.0
#
#    _PHYS14D  _MENT14D
# 0       1.0       1.0
# 1       1.0       1.0
# 2       2.0       9.0
# 3       1.0       1.0
# 4       2.0       2.0
# 5       1.0       1.0
# 6       2.0       2.0
# ...

# %%
test = ToBinary(df4,'SDHUTILS', inf_replacement=7, nan_replacement=7)
test = ToBinary(test,'SDHTRNSP', inf_replacement=7, nan_replacement=7)
test = ToBinary(test,'RRPHYSM2', inf_replacement=7, nan_replacement=7)
test.head(10)
# Out:
# [0 1 7 9]
# [0 7 1 9]
# [7 0 9 1]
#    SDHUTILS  SDHTRNSP  SDHSTRE1  RRTREAT  RRHCARE4  RRPHYSM2  _RFHLTH  \
# 0         0         0       5.0      NaN       NaN         7      1.0
# 1         1         0       5.0      NaN       NaN         7      1.0
# 2         0         0       4.0      NaN       NaN         7      1.0
# 3         0         0       5.0      NaN       NaN         7      1.0
# 4         0         0       4.0      NaN       NaN         7      2.0
# 5         0         0       4.0      NaN       NaN         7      1.0
# 6         0         0       5.0      NaN       NaN         7      1.0
# 7         0         0       5.0      NaN       NaN         7      1.0
# 8         0         0       4.0      NaN       NaN         7      1.0
# 9         0         0       3.0      NaN       NaN         7      1.0
#
#    _PHYS14D  _MENT14D
# 0       1.0       1.0
# 1       1.0       1.0
# 2       2.0       9.0
# 3       1.0       1.0
# 4       2.0       2.0
# ...

# %%
# test = ToOrdinal(test,'SDHSTRE1', Never=5, Never_to_0=True) ordinal 先不处理
# test.head(10)
# print(test['SDHSTRE1'].unique())

# %%
test = ToNominal(test, 'RRTREAT', ['RaceTreat-Worse', 'RaceTreat-Same', 'RaceTreat-Better', 'RaceTreat-Better or Worse','RaceTreat-Only Encounter Same', 'Missing', 'Missing','Missing'])
test['RRTREAT'].unique()
# Out:
# array(['Missing', 'RaceTreat-Same', 'RaceTreat-Better', 'RaceTreat-Worse',
#        'RaceTreat-Better or Worse', 'RaceTreat-Only Encounter Same'],
#       dtype=object)

# %%
test = ToNominal(test, 'RRHCARE4', ['RaceTreat2-Worse than other', 'RaceTreat2-Same as other', 'RaceTreat2-Better than other', 'RaceTreat2-Better or Worse','RaceTreat2-Only Encounter Same', 'Missing','Missing', 'Missing', 'Missing'])
test['RRHCARE4'].unique()
# Out:
# array(['Missing', 'RaceTreat2-Same as other',
#        'RaceTreat2-Better than other', 'RaceTreat2-Only Encounter Same',
#        'RaceTreat2-Worse than other', 'RaceTreat2-Better or Worse'],
#       dtype=object)

# %%
test.head(10)
# Out:
#    SDHUTILS  SDHTRNSP  SDHSTRE1  RRTREAT RRHCARE4  RRPHYSM2  _RFHLTH  \
# 0         0         0       5.0  Missing  Missing         7      1.0
# 1         1         0       5.0  Missing  Missing         7      1.0
# 2         0         0       4.0  Missing  Missing         7      1.0
# 3         0         0       5.0  Missing  Missing         7      1.0
# 4         0         0       4.0  Missing  Missing         7      2.0
# 5         0         0       4.0  Missing  Missing         7      1.0
# 6         0         0       5.0  Missing  Missing         7      1.0
# 7         0         0       5.0  Missing  Missing         7      1.0
# 8         0         0       4.0  Missing  Missing         7      1.0
# 9         0         0       3.0  Missing  Missing         7      1.0
#
#    _PHYS14D  _MENT14D
# 0       1.0       1.0
# 1       1.0       1.0
# 2       2.0       9.0
# 3       1.0       1.0
# 4       2.0       2.0
# 5       1.0       1.0
# 6       2.0       2.0
# ...

# %%
test = ToNominal(test, '_RFHLTH', ['Health-Good or Better','Health-Fair or Poor', 'Missing'])
test['_RFHLTH'].unique()
# Out:
# array(['Health-Good or Better', 'Health-Fair or Poor', 'Missing'],
#       dtype=object)

# %%
test.head(10)
# Out:
#    SDHUTILS  SDHTRNSP  SDHSTRE1  RRTREAT RRHCARE4  RRPHYSM2  \
# 0         0         0       5.0  Missing  Missing         7
# 1         1         0       5.0  Missing  Missing         7
# 2         0         0       4.0  Missing  Missing         7
# 3         0         0       5.0  Missing  Missing         7
# 4         0         0       4.0  Missing  Missing         7
# 5         0         0       4.0  Missing  Missing         7
# 6         0         0       5.0  Missing  Missing         7
# 7         0         0       5.0  Missing  Missing         7
# 8         0         0       4.0  Missing  Missing         7
# 9         0         0       3.0  Missing  Missing         7
#
#                  _RFHLTH  _PHYS14D  _MENT14D
# 0  Health-Good or Better       1.0       1.0
# 1  Health-Good or Better       1.0       1.0
# 2  Health-Good or Better       2.0       9.0
# 3  Health-Good or Better       1.0       1.0
# 4    Health-Fair or Poor       2.0       2.0
# ...

# %%
test = ToNominal(test, '_PHYS14D', ['Health not good:0day','Health not good:1-13day','Health not good:14+day', 'Missing'])
test['_PHYS14D'].unique()
# Out:
# array(['Health not good:0day', 'Health not good:1-13day',
#        'Health not good:14+day', 'Missing'], dtype=object)

# %%
test = ToNominal(test, '_MENT14D', ['mental not good:0day','mental not good:1-13day','mental not good:14+day', 'Missing'])
test['_MENT14D'].unique()
# Out:
# array(['mental not good:0day', 'Missing', 'mental not good:1-13day',
#        'mental not good:14+day'], dtype=object)

# %%
test.head(10)
# Out:
#    SDHUTILS  SDHTRNSP  SDHSTRE1  RRTREAT RRHCARE4  RRPHYSM2  \
# 0         0         0       5.0  Missing  Missing         7
# 1         1         0       5.0  Missing  Missing         7
# 2         0         0       4.0  Missing  Missing         7
# 3         0         0       5.0  Missing  Missing         7
# 4         0         0       4.0  Missing  Missing         7
# 5         0         0       4.0  Missing  Missing         7
# 6         0         0       5.0  Missing  Missing         7
# 7         0         0       5.0  Missing  Missing         7
# 8         0         0       4.0  Missing  Missing         7
# 9         0         0       3.0  Missing  Missing         7
#
#                  _RFHLTH                 _PHYS14D                 _MENT14D
# 0  Health-Good or Better     Health not good:0day     mental not good:0day
# 1  Health-Good or Better     Health not good:0day     mental not good:0day
# 2  Health-Good or Better  Health not good:1-13day                  Missing
# ...

# %%
test.SDHTRNSP.value_counts()
# Out:
# SDHTRNSP
# 0    49821
# 7    11376
# 1     2365
# 9       68
# Name: count, dtype: int64

# %%
test = OneHotEncoding(test)

# %%
test.drop(columns=['SDHUTILS', 'SDHTRNSP', 'RRPHYSM2'], inplace=True)
test = Impute(test, 'SDHSTRE1')

# %%
test.shape
# Out:
# (63630, 19)

# %%
# test = ToNominal(test,'_ASTHMS1', ['Asthma_current','Asthma_former','Asthma_never','Asthma_missing'])

# %%
# test = OneHotEncoding(test)

# %%
# #'_TOTINDA','_MICHD','_ASTHMS1','_DRDXAR2','_CHLDCNT','_EDUCAG','_INCOMG1','_SMOKER3','_CURECI2'
# test = Impute(test,'_TOTINDA',Unknown=7, Missing=9)
# test = Impute(test, '_MICHD')
# test = Impute(test,'_DRDXAR2')
# test = Impute(test,'_CHLDCNT',Unknown=7, Missing=9)
# test = Impute(test,'_EDUCAG',Unknown=7, Missing=9)
# test = Impute(test,'_INCOMG1',Unknown=7,Missing=9)
# test = Impute(test,'_SMOKER3',Unknown=7,Missing=9)
# test = Impute(test,'_CURECI2',Unknown=7,Missing=9)

# %%
# test._CURECI2.value_counts()

# %%
test.to_csv('/content/drive/MyDrive/Colab Notebooks/Data Mining/Data/Zhiquan.csv',index=True)
